# %% [markdown]
# # Dataset from HuggingFace

# %%
# !pip3 install datasets
# !wget https://raw.githubusercontent.com/sighsmile/conlleval/master/conlleval.py
# Out:
# Collecting datasets
#   Using cached datasets-2.10.1-py3-none-any.whl (469 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
# Requirement already satisfied: pandas in c:\users\renan\anaconda3\lib\site-packages (from datasets) (1.5.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\renan\anaconda3\lib\site-packages (from datasets) (4.62.3)
# Collecting dill<0.3.7,>=0.3.0
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\users\renan\anaconda3\lib\site-packages (from datasets) (9.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp38-cp38-win_amd64.whl (324 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in c:\users\renan\anaconda3\lib\site-packages (from datasets) (0.11.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-win_amd64.whl (30 kB)
# Requirement already satisfied: packaging in c:\users\renan\anaconda3\lib\site-packages (from datasets) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\renan\anaconda3\lib\site-packages (from datasets) (1.24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\renan\anaconda3\lib\site-packages (from datasets) (5.3.1)
# Collecting responses<0.19
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\renan\anaconda3\lib\site-packages (from datasets) (2.24.0)
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2023.3.0-py3-none-any.whl (145 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\renan\anaconda3\lib\site-packages (from pandas->datasets) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\renan\anaconda3\lib\site-packages (from pandas->datasets) (2020.1)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\renan\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\renan\anaconda3\lib\site-packages (from aiohttp->datasets) (20.3.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp38-cp38-win_amd64.whl (56 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp38-cp38-win_amd64.whl (34 kB)
# Collecting charset-normalizer<4.0,>=2.0
#   Downloading charset_normalizer-3.1.0-cp38-cp38-win_amd64.whl (96 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp38-cp38-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\renan\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.7.4.3)
# Requirement already satisfied: filelock in c:\users\renan\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.0.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\renan\anaconda3\lib\site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: urllib3>=1.25.10 in c:\users\renan\anaconda3\lib\site-packages (from responses<0.19->datasets) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\renan\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\renan\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\renan\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: six>=1.5 in c:\users\renan\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.15.0)
# Installing collected packages: dill, multiprocess, multidict, yarl, frozenlist, charset-normalizer, aiosignal, async-timeout, aiohttp, xxhash, responses, fsspec, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 0.8.3
#     Uninstalling fsspec-0.8.3:
#       Successfully uninstalled fsspec-0.8.3
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 charset-normalizer-3.1.0 datasets-2.10.1 dill-0.3.6 frozenlist-1.3.3 fsspec-2023.3.0 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Import Modules

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers
from datasets import load_dataset
from collections import Counter
from conlleval import evaluate

# %% [markdown]
# # The Transformer
# Creating a transformer block

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super().__init__()
        self.att = keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential([keras.layers.Dense(ff_dim, activation="relu"),
                                     keras.layers.Dense(embed_dim),])
        self.layernorm1 = keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = keras.layers.Dropout(rate)
        self.dropout2 = keras.layers.Dropout(rate)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %% [markdown]
# Define a token and position embedding layer

# %%
class TokenAndPositionEmbedding(layers.Layer):
    def __init__(self, maxlen, vocab_size, embed_dim):
        super().__init__()
        self.token_emb = keras.layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)
        self.pos_emb = keras.layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, inputs):
        maxlen = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=maxlen, delta=1)
        position_embeddings = self.pos_emb(positions)
        token_embeddings = self.token_emb(inputs)
        return token_embeddings + position_embeddings

# %% [markdown]
# # NER Model

# %%
class NERModel(keras.Model):
    def __init__(self, num_tags, vocab_size, maxlen=128, embed_dim=32, num_heads=2, ff_dim=32):
        super().__init__()
        self.embedding_layer = TokenAndPositionEmbedding(maxlen, vocab_size, embed_dim)
        self.transformer_block = TransformerBlock(embed_dim, num_heads, ff_dim)
        self.dropout1 = layers.Dropout(0.1)
        self.ff = layers.Dense(ff_dim, activation="relu")
        self.dropout2 = layers.Dropout(0.1)
        self.ff_final = layers.Dense(num_tags, activation="softmax")

    def call(self, inputs, training=False):
        x = self.embedding_layer(inputs)
        x = self.transformer_block(x)
        x = self.dropout1(x, training=training)
        x = self.ff(x)
        x = self.dropout2(x, training=training)
        x = self.ff_final(x)
        return x

# %% [markdown]
# # Load Dataset

# %%
conll_data = load_dataset("conll2003")
# Out:
# Found cached dataset conll2003 (C:/Users/Renan/.cache/huggingface/datasets/conll2003/conll2003/1.0.0/9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
# 100%|██████████| 3/3 [00:00<00:00, 88.22it/s]

# %% [markdown]
# Export data to a file

# %%
def export_to_file(export_file_path, data):
    with open(export_file_path, "w") as f:
        for record in data:
            ner_tags = record["ner_tags"]
            tokens = record["tokens"]
            if len(tokens) > 0:
                f.write(
                    str(len(tokens))
                    + "\t"
                    + "\t".join(tokens)
                    + "\t"
                    + "\t".join(map(str, ner_tags))
                    + "\n"
                )


os.mkdir("data")
export_to_file("./data/conll_train.txt", conll_data["train"])
export_to_file("./data/conll_val.txt",   conll_data["validation"])

# %% [markdown]
# Label preparaiton (a lookup table)

# %%
def make_tag_lookup_table():
    iob_labels = ["B", "I"]
    ner_labels = ["PER", "ORG", "LOC", "MISC"]
    all_labels = [(label1, label2) for label2 in ner_labels for label1 in iob_labels]
    all_labels = ["-".join([a, b]) for a, b in all_labels]
    all_labels = ["[PAD]", "O"] + all_labels
    return dict(zip(range(0, len(all_labels) + 1), all_labels))


mapping = make_tag_lookup_table()
print(mapping)
# Out:
# {0: '[PAD]', 1: 'O', 2: 'B-PER', 3: 'I-PER', 4: 'B-ORG', 5: 'I-ORG', 6: 'B-LOC', 7: 'I-LOC', 8: 'B-MISC', 9: 'I-MISC'}

# %% [markdown]
# Create a dictionary of vocaburaries

# %%
all_tokens = sum(conll_data["train"]["tokens"], [])
all_tokens_array = np.array(list(map(str.lower, all_tokens)))

counter = Counter(all_tokens_array)
print(len(counter))

num_tags = len(mapping)
vocab_size = 20000

# We only take (vocab_size - 2) most commons words from the training data since
# the `StringLookup` class uses 2 additional tokens - one denoting an unknown
# token and another one denoting a masking token
vocabulary = [token for token, count in counter.most_common(vocab_size - 2)]

# The StringLook class will convert tokens to token IDs
lookup_layer = keras.layers.StringLookup(vocabulary=vocabulary)
# Out:
# 21009

# %% [markdown]
# Creating `training set` and `validation set`

# %%
train_data = tf.data.TextLineDataset("./data/conll_train.txt")
val_data = tf.data.TextLineDataset("./data/conll_val.txt")

# %% [markdown]
# Explore the data

# %%
print(list(train_data.take(1).as_numpy_iterator()))
# Out:
# [b'9\tEU\trejects\tGerman\tcall\tto\tboycott\tBritish\tlamb\t.\t3\t0\t7\t0\t0\t0\t7\t0\t0']

# %% [markdown]
# Generating the dataset

# %%
def map_record_to_training_data(record):
    record = tf.strings.split(record, sep="\t")
    length = tf.strings.to_number(record[0], out_type=tf.int32)
    tokens = record[1 : length + 1]
    tags = record[length + 1 :]
    tags = tf.strings.to_number(tags, out_type=tf.int64)
    tags += 1
    return tokens, tags


def lowercase_and_convert_to_ids(tokens):
    tokens = tf.strings.lower(tokens)
    return lookup_layer(tokens)


# We use `padded_batch` here because each record in the dataset has a
# different length.
batch_size = 32
train_dataset = (
    train_data.map(map_record_to_training_data)
    .map(lambda x, y: (lowercase_and_convert_to_ids(x), y))
    .padded_batch(batch_size)
)
val_dataset = (
    val_data.map(map_record_to_training_data)
    .map(lambda x, y: (lowercase_and_convert_to_ids(x), y))
    .padded_batch(batch_size)
)

ner_model = NERModel(num_tags, vocab_size, embed_dim=32, num_heads=4, ff_dim=64)
# Out:
# WARNING:tensorflow:From c:\Users\Renan\anaconda3\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# Define a custom loss to ignore the padded tokens

# %%
class CustomNonPaddingTokenLoss(keras.losses.Loss):
    def __init__(self, name="custom_ner_loss"):
        super().__init__(name=name)

    def call(self, y_true, y_pred):
        loss_fn = keras.losses.SparseCategoricalCrossentropy(
            from_logits=True, reduction=keras.losses.Reduction.NONE
        )
        loss = loss_fn(y_true, y_pred)
        mask = tf.cast((y_true > 0), dtype=tf.float32)
        loss = loss * mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

loss = CustomNonPaddingTokenLoss()

# %% [markdown]
# Compile and fit the model

# %%
ner_model.compile(optimizer="adam", loss=loss)
ner_model.fit(train_dataset, epochs=30)


def tokenize_and_convert_to_ids(text):
    tokens = text.split()
    return lowercase_and_convert_to_ids(tokens)


# Sample inference using the trained model
sample_input = tokenize_and_convert_to_ids(
    "eu rejects german call to boycott british lamb"
)
sample_input = tf.reshape(sample_input, shape=[1, -1])
print(sample_input)

output = ner_model.predict(sample_input)
prediction = np.argmax(output, axis=-1)[0]
prediction = [mapping[i] for i in prediction]

# eu -> B-ORG, german -> B-MISC, british -> B-MISC
print(prediction)

# %%
ner_model.summary()
# Out:
# Model: "ner_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  token_and_position_embeddin  multiple                 644096
#  g (TokenAndPositionEmbeddin
#  g)
#
#  transformer_block (Transfor  multiple                 21120
#  merBlock)
#
#  dropout_2 (Dropout)         multiple                  0
#
#  dense_2 (Dense)             multiple                  2112
#
#  dropout_3 (Dropout)         multiple                  0
#
#  dense_3 (Dense)             multiple                  650
#
# =================================================================
# Total params: 667,978
# Trainable params: 667,978
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Define evaluation metrics.  The appropriate metrics is F1 score

# %%
def calculate_metrics(dataset):
    all_true_tag_ids, all_predicted_tag_ids = [], []

    for x, y in dataset:
        output = ner_model.predict(x)
        predictions = np.argmax(output, axis=-1)
        predictions = np.reshape(predictions, [-1])

        true_tag_ids = np.reshape(y, [-1])

        mask = (true_tag_ids > 0) & (predictions > 0)
        true_tag_ids = true_tag_ids[mask]
        predicted_tag_ids = predictions[mask]

        all_true_tag_ids.append(true_tag_ids)
        all_predicted_tag_ids.append(predicted_tag_ids)

    all_true_tag_ids = np.concatenate(all_true_tag_ids)
    all_predicted_tag_ids = np.concatenate(all_predicted_tag_ids)

    predicted_tags = [mapping[tag] for tag in all_predicted_tag_ids]
    real_tags = [mapping[tag] for tag in all_true_tag_ids]

    evaluate(real_tags, predicted_tags)


calculate_metrics(val_dataset)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# processed 51362 tokens with 5942 phrases; found: 5844 phrases; correct: 4078.
# accuracy:  66.60%; (non-O)
# accuracy:  93.37%; precision:  69.78%; recall:  68.63%; FB1:  69.20
#               LOC: precision:  82.97%; recall:  79.80%; FB1:  81.35  1767
#              MISC: precision:  72.88%; recall:  66.16%; FB1:  69.36  837
#               ORG: precision:  55.14%; recall:  66.82%; FB1:  60.42  1625
#               PER: precision:  68.48%; recall:  60.04%; FB1:  63.99  1615
